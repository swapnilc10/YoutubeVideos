# %%
import pandas as pd

# %%
df=pd.read_csv('dummy_data.csv')

# %%
df.head(10)
# Out:
#    age      gender  time_spent   platform  interests        location  \
# 0   56        male           3  Instagram     Sports  United Kingdom
# 1   46      female           2   Facebook     Travel  United Kingdom
# 2   32        male           8  Instagram     Sports       Australia
# 3   60  non-binary           5  Instagram     Travel  United Kingdom
# 4   25        male           1  Instagram  Lifestlye       Australia
# 5   38        male           3   Facebook     Travel   United States
# 6   56        male           8    YouTube     Sports   United States
# 7   36        male           4  Instagram     Sports       Australia
# 8   40  non-binary           7    YouTube  Lifestlye       Australia
# 9   28  non-binary           2  Instagram     Sports       Australia
#
#   demographics         profession  income  indebt  isHomeOwner  Owns_Car
# 0        Urban  Software Engineer   19774    True        False     False
# ...

# %%
#loc[row label,column label] #include the endpoints

# %%
df.loc[1,'gender']
# Out:
# 'female'

# %%
df.loc[4]
# Out:
# age                            25
# gender                       male
# time_spent                      1
# platform                Instagram
# interests               Lifestlye
# location                Australia
# demographics                Urban
# profession      Software Engineer
# income                      14566
# indebt                      False
# isHomeOwner                  True
# Owns_Car                     True
# Name: 4, dtype: object

# %%
df.loc[[3,6,8]]
# Out:
#    age      gender  time_spent   platform  interests        location  \
# 3   60  non-binary           5  Instagram     Travel  United Kingdom
# 6   56        male           8    YouTube     Sports   United States
# 8   40  non-binary           7    YouTube  Lifestlye       Australia
#
#   demographics        profession  income  indebt  isHomeOwner  Owns_Car
# 3        Urban           Student   12500   False         True     False
# 6        Urban           Student   16881    True         True      True
# 8    Sub_Urban  Marketer Manager   16030   False        False      True

# %%
df.loc[1:10,'time_spent']
# Out:
# 1     2
# 2     8
# 3     5
# 4     1
# 5     3
# 6     8
# 7     4
# 8     7
# 9     2
# 10    7
# Name: time_spent, dtype: int64

# %%
df.loc[1:10,['age','gender']]
# Out:
#     age      gender
# 1    46      female
# 2    32        male
# 3    60  non-binary
# 4    25        male
# 5    38        male
# 6    56        male
# 7    36        male
# 8    40  non-binary
# 9    28  non-binary
# 10   28      female

# %%
df.loc[lambda df:df['age']%2==0]
# Out:
#      age      gender  time_spent   platform  interests        location  \
# 0     56        male           3  Instagram     Sports  United Kingdom
# 1     46      female           2   Facebook     Travel  United Kingdom
# 2     32        male           8  Instagram     Sports       Australia
# 3     60  non-binary           5  Instagram     Travel  United Kingdom
# 5     38        male           3   Facebook     Travel   United States
# ..   ...         ...         ...        ...        ...             ...
# 990   60      female           9    YouTube  Lifestlye       Australia
# 991   20  non-binary           7   Facebook     Travel       Australia
# 992   50      female           9    YouTube     Travel       Australia
# 995   22      female           8  Instagram  Lifestlye  United Kingdom
# 996   40  non-binary           6    YouTube     Travel  United Kingdom
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# ...

# %%
df[df['age']%2==0]
# Out:
#      age      gender  time_spent   platform  interests        location  \
# 0     56        male           3  Instagram     Sports  United Kingdom
# 1     46      female           2   Facebook     Travel  United Kingdom
# 2     32        male           8  Instagram     Sports       Australia
# 3     60  non-binary           5  Instagram     Travel  United Kingdom
# 5     38        male           3   Facebook     Travel   United States
# ..   ...         ...         ...        ...        ...             ...
# 990   60      female           9    YouTube  Lifestlye       Australia
# 991   20  non-binary           7   Facebook     Travel       Australia
# 992   50      female           9    YouTube     Travel       Australia
# 995   22      female           8  Instagram  Lifestlye  United Kingdom
# 996   40  non-binary           6    YouTube     Travel  United Kingdom
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# ...

# %%
df.loc[df['age']%2==0]
# Out:
#      age      gender  time_spent   platform  interests        location  \
# 0     56        male           3  Instagram     Sports  United Kingdom
# 1     46      female           2   Facebook     Travel  United Kingdom
# 2     32        male           8  Instagram     Sports       Australia
# 3     60  non-binary           5  Instagram     Travel  United Kingdom
# 5     38        male           3   Facebook     Travel   United States
# ..   ...         ...         ...        ...        ...             ...
# 990   60      female           9    YouTube  Lifestlye       Australia
# 991   20  non-binary           7   Facebook     Travel       Australia
# 992   50      female           9    YouTube     Travel       Australia
# 995   22      female           8  Instagram  Lifestlye  United Kingdom
# 996   40  non-binary           6    YouTube     Travel  United Kingdom
#
#     demographics         profession  income  indebt  isHomeOwner  Owns_Car
# ...

# %%
#iloc[row index,column index]

# %%
df.iloc[:,0:3] #excludes the endpoints
# Out:
#      age      gender  time_spent
# 0     56        male           3
# 1     46      female           2
# 2     32        male           8
# 3     60  non-binary           5
# 4     25        male           1
# ..   ...         ...         ...
# 995   22      female           8
# 996   40  non-binary           6
# 997   27  non-binary           5
# 998   61      female           4
# 999   19      female           8
#
# [1000 rows x 3 columns]

# %%
df.iloc[0:3,0]
# Out:
# 0    56
# 1    46
# 2    32
# Name: age, dtype: int64

# %%
#Creating a sample DataFrame
data = {'A': [1, 2, 3,4], 'B': [4, 5, 6,7], 'C': [7, 8, 9,10]}
df1 = pd.DataFrame(data, index=['D', 'A', 'T','A'])

# %%
df1.head()
# Out:
#    A  B   C
# D  1  4   7
# A  2  5   8
# T  3  6   9
# A  4  7  10

# %%
df1.loc['D']
# Out:
# A    1
# B    4
# C    7
# Name: D, dtype: int64

# %%
df1.iloc[0]
# Out:
# A    1
# B    4
# C    7
# Name: D, dtype: int64
